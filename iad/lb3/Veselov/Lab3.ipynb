# %% [markdown]
# 18-АС Веселов В А Вариант 2 6

# %%
# !pip install deepface
from deepface import DeepFace
import cv2
import pandas as pd
import matplotlib.pyplot as plt

# %%
"""обнаружение лиц"""

def detect_face(img):
    detected_face = DeepFace.detectFace(img, detector_backend = 'ssd')
    plt.imshow(cv2.cvtColor(detected_face, cv2.COLOR_BGR2RGB))

# %%
"""Вывод оригинальной фотки"""

def detect_face_orig(img):
    orig = cv2.imread(img)
    plt.imshow(cv2.cvtColor(orig, cv2.COLOR_BGR2RGB))

# %%
"""сравнение """

def verify_images(img1, img2):
    obj = DeepFace.verify(img1, img2, distance_metric='euclidean', model_name='Dlib', detector_backend = 'ssd')
    return obj

# %%
"""функция вывода результата"""

def get_verification_results(result):
  print(result)

# %%
imgs = [f'/content/drive/MyDrive/Лабораторные_ИАД/Лаб3/Фото/{i}.jpg' for i in range(1,9)]
results = []

# %%
detect_face_orig(imgs[0])

# %%
detect_face_orig(imgs[1])

# %%
detect_face_orig(imgs[2])

# %%
detect_face(imgs[0])

# %%
detect_face(imgs[1])

# %%
detect_face(imgs[2])

# %%
get_verification_results(verify_images(imgs[1], imgs[0]))
# Out:
# {'verified': True, 'distance': 0.5869578987140165, 'max_threshold_to_verify': 0.6, 'model': 'Dlib', 'similarity_metric': 'euclidean'}

# %%
get_verification_results(verify_images(imgs[1], imgs[0]))
# Out:
# {'verified': True, 'distance': 0.5869578987140165, 'max_threshold_to_verify': 0.6, 'model': 'Dlib', 'similarity_metric': 'euclidean'}

# %%
get_verification_results(verify_images(imgs[0], imgs[2]))
# Out:
# {'verified': False, 'distance': 0.6190440115715737, 'max_threshold_to_verify': 0.6, 'model': 'Dlib', 'similarity_metric': 'euclidean'}

# %%
detect_face(imgs[6])

# %%
def check(path2video):
  print("Start")
  cap = cv2.VideoCapture(path2video)
  while True:
    grab, original_img = cap.read()
    if not grab:
      print("End of video")
      break

    cap.read
    ssd_img = original_img.copy()
    try:
      obj = DeepFace.verify(imgs[6], original_img, distance_metric='euclidean', model_name='Dlib', detector_backend = 'ssd')
    except ValueError:
      print('Can not find face')
    else:
      if obj['verified']:
        cap.release()
        cv2.destroyAllWindows()
        print("Welcome!!!")
        print("End of video")
        break

# %%
def play_video(path2video):
  cap = cv2.VideoCapture(path2video)
  while True:
    grab, original_img = cap.read()
    if not grab:
      break
    plt.imshow(cv2.cvtColor(original_img, cv2.COLOR_BGR2RGB))

# %%
play_video('/content/drive/MyDrive/Лабораторные_ИАД/Лаб3/Видео/1.avi')

# %%
check('/content/drive/MyDrive/Лабораторные_ИАД/Лаб3/Видео/1.avi')
# Out:
# Start
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# ...

# %%
play_video('/content/drive/MyDrive/Лабораторные_ИАД/Лаб3/Видео/2.avi')

# %%
check('/content/drive/MyDrive/Лабораторные_ИАД/Лаб3/Видео/2.avi')
# Out:
# Start
# Welcome!!!

# %%
play_video('/content/drive/MyDrive/Лабораторные_ИАД/Лаб3/Видео/3.avi')

# %%
check('/content/drive/MyDrive/Лабораторные_ИАД/Лаб3/Видео/3.avi')
# Out:
# Start
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# Can not find face
# ...
